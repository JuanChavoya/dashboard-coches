# %% [markdown]
# # Análisis Exploratorio de Datos - Vehículos
# ## Dataset: vehicles_us.csv

# %%
import pandas as pd
import plotly.graph_objects as go

# Cargar datos
car_data = pd.read_csv('../vehicles_us.csv')
print('Dimensiones:', car_data.shape)
print('\nPrimeras filas:')
car_data.head()
